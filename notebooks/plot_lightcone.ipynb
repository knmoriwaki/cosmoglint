# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import json
import argparse
import copy

import h5py

from matplotlib.colors import LogNorm

from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=67.74, Om0=0.3089)
hlittle = cosmo.H0.value / 100

from astropy import units as u

from lightcone_utils import load_data, show_map, plot_mean

### Load data
base_dir = "../dataset/generated_data_lightcone"
output_dir = "{}/figures".format(base_dir)
os.makedirs(output_dir, exist_ok=True)

from line_model import line_dict 
line_names = list(line_dict.keys())
NLINE = len(line_names)

# %%
fname = "{}/pinocchio.run.3600sec_fmin248_fmax301_R500.h5".format(base_dir)
freq, intensity, intensity_line, attrs = load_data(fname)
side_length = attrs['side_length']
lines_to_show = ["CO(2-1)", "CO(3-2)", "CO(4-3)", "CO(5-4)", "CO(6-5)", "CO(7-6)", "[CII]158", "[CI](1-0)"]
show_map(freq, intensity, intensity_line, side_length, dy=-1, lines_to_show=lines_to_show)
# Out:
# # Load ./generated_data/pinocchio.run.3600sec_fmin248_fmax301_R500.h5
# Total intensity CO(4-3): 9.522245e+07
# Total intensity CO(5-4): 4.887346e+07
# Total intensity CO(6-5): 4.535403e+07
# Total intensity CO(7-6): 2.788185e+07
# Total intensity CO(8-7): 2.225183e+07
# Total intensity CO(9-8): 1.945620e+07
# Total intensity CO(10-9): 9.607133e+06
# Total intensity CO(11-10): 7.146221e+06
# Total intensity CO(12-11): 3.622203e+06
# Total intensity CO(13-12): 1.399242e+05
# Total intensity [CII]158: 9.844507e+06
# Total intensity [CI](1-0): 5.485835e+07
# Total intensity [CI](2-1): 2.408994e+07
# freqency shape:  (96,)
# intensity shape:  (120, 120, 95)
# Projection along y-axis: 120 slices
# Warning: CO(2-1) not found in intensity_line, skipping...
# Warning: CO(3-2) not found in intensity_line, skipping...

# %%
fname = "{}/pinocchio.run.3600sec_fmin100_fmax1000_R20.h5".format(base_dir)
freq, intensity, intensity_line, attrs = load_data(fname)
side_length = attrs['side_length']
plot_mean(freq, intensity, intensity_line, logx=True, nsmooth=4, ylim=(1e-1, 2e3))
# Out:
# # Load ./generated_data/pinocchio.run.3600sec_fmin100_fmax1000_R20.h5
# Total intensity CO(2-1): 7.161032e+06
# Total intensity CO(3-2): 2.774315e+07
# Total intensity CO(4-3): 1.583122e+07
# Total intensity CO(5-4): 1.368888e+07
# Total intensity CO(6-5): 1.012386e+07
# Total intensity CO(7-6): 7.315498e+06
# Total intensity CO(8-7): 7.218236e+06
# Total intensity CO(9-8): 5.720628e+06
# Total intensity CO(10-9): 4.315055e+06
# Total intensity CO(11-10): 3.921347e+06
# Total intensity CO(12-11): 2.615607e+06
# Total intensity CO(13-12): 1.640986e+05
# Total intensity [CII]158: 1.218358e+08
# Total intensity [CI](1-0): 1.021436e+07
# Total intensity [CI](2-1): 6.467382e+06
# freqency shape:  (47,)
# intensity shape:  (120, 120, 46)
# Warning: CO(1-0) not found in intensity_line, skipping...
